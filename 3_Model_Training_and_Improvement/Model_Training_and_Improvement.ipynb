# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import pickle

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, FunctionTransformer

from sklearn.linear_model import LogisticRegression, Lasso, Ridge, ElasticNet

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.metrics import classification_report, roc_curve

# %% [markdown]
# ## Misc notes

# %% [markdown]
# conda env create
# Docker
# ML Flow

# %% [markdown]
# pareidolia

# %% [markdown]
# sklearn pipelines
# luigi

# %% [markdown]
# sklearn make_column_selector

# %% [markdown]
# pickle in python

# %% [markdown]
# irreducible error (noise) - неизбежна грешка
#
# variance, statistical error
#
# bias, assumption error

# %% [markdown]
# L1 Regularization (Lasso):
#
# Minimizes the sum of absolute values of the coefficients.
# Encourages sparsity by forcing some coefficients to be exactly zero, which helps in feature selection.
#
# L2 Regularization (Ridge):
#
# Minimizes the sum of squares of the coefficients.
# Discourages large weights but keeps all coefficients small rather than setting some of them to zero.
#
# L0 Regularization:
#
# Counts the number of non-zero parameters. Ideally, it would produce the sparsest possible model, but it's hard to optimize and not used in practice.
#
# L∞ Regularization:
#
# Minimizes the maximum absolute value of the coefficients, controlling the influence of the largest weight and ensuring robustness to extremes.

# %% [markdown]
# hyperopt (also for sklearn) - alternative to GridSearchCV
#
# optuna - mostly for neural networks
#
# Yellowbrick - visualization library

# %% [markdown]
# ## Lecture demo

# %%
EPS = 1e-10

# %%
diabetes_data = pd.read_csv("data/diabetic_data.csv")

# %%
diabetes_data.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
diabetes_data.columns[diabetes_data.columns.str.contains("_id")]
# Out:
# Index(['encounter_id', 'admission_type_id', 'discharge_disposition_id',
#        'admission_source_id'],
#       dtype='object')

# %%
diabetes_data.pioglitazone.unique()
# Out:
# array(['No', 'Steady', 'Up', 'Down'], dtype=object)

# %%
diabetes_data.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# glipizide                   object
# glyburide                   object
# tolbutamide                 object
# pioglitazone                object
# rosiglitazone               object
# acarbose                    object
# miglitol                    object
# troglitazone                object
# tolazamide                  object
# examide                     object
# citoglipton                 object
# insulin                     object
# glyburide-metformin         object
# glipizide-metformin         object
# glimepiride-pioglitazone    object
# metformin-rosiglitazone     object
# metformin-pioglitazone      object
# change                      object
# diabetesMed                 object
# readmitted                  object
# dtype: object

# %%
diabetes_attributes = diabetes_data.drop(columns = "readmitted")
diabetes_target = diabetes_data.readmitted

# %%
diabetes_attributes_dummies = pd.get_dummies(diabetes_attributes)

# %%
logistic_regression = LogisticRegression()

# %%
logistic_regression.fit(diabetes_attributes_dummies, diabetes_target)
# Out:
# LogisticRegression()

# %%
logistic_regression.coef_
# Out:
# array([[-3.31701395e-09, -3.86905107e-09, -1.15814534e-15, ...,
#         -3.26369841e-16, -1.63318872e-16, -3.02903976e-16],
#        [-1.50329991e-10,  4.51003945e-09, -1.47130836e-16, ...,
#         -1.14848644e-16, -1.11876233e-16,  7.41720589e-17],
#        [ 3.46734394e-09, -6.40988385e-10,  1.30527618e-15, ...,
#          4.41218484e-16,  2.75195106e-16,  2.28731917e-16]])

# %%
scaler = MinMaxScaler()

# %%
diabetes_attributes_scaled = scaler.fit_transform(diabetes_attributes_dummies)

# %%
logistic_regression.fit(diabetes_attributes_scaled, diabetes_target)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_regression.score(diabetes_attributes_scaled, diabetes_target)
# Out:
# 0.5951987893795571

# %%
logistic_regression.score(diabetes_attributes_dummies, diabetes_target)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
# 0.5386966177308727

# %%
pipeline = Pipeline([
    ("scaler", MinMaxScaler()),
    ("model", LogisticRegression())
])

# %%
pipeline
# Out:
# Pipeline(steps=[('scaler', MinMaxScaler()), ('model', LogisticRegression())])

# %%
sample_data = diabetes_data.sample(5000, random_state = 42)

# %%
sample_attributes = sample_data.drop(columns = "readmitted")

# %%
sample_target = sample_data.readmitted

# %%
sample_attributes = pd.get_dummies(sample_attributes)

# %%
pipeline.fit(sample_attributes, sample_target)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('scaler', MinMaxScaler()), ('model', LogisticRegression())])

# %%
ohe = OneHotEncoder()

# %%
sample_data.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
categorical_columns = sample_data.dtypes[sample_data.dtypes == np.object_].index.values

# %%
categorical_columns = categorical_columns[:-1]

# %%
categorical_columns
# Out:
# array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone',
#        'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide',
#        'citoglipton', 'insulin', 'glyburide-metformin',
#        'glipizide-metformin', 'glimepiride-pioglitazone',
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#        'diabetesMed'], dtype=object)

# %%
numerical_columns = [
    'admission_type_id', 'discharge_disposition_id', 'time_in_hospital', 'num_lab_procedures', 'num_procedures',
    'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'number_diagnoses'
]

# %%
preprocessor = ColumnTransformer([
    ("categorical", OneHotEncoder(), categorical_columns),
    ("numerical", MinMaxScaler(), numerical_columns)
], remainder = "passthrough")

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('categorical', OneHotEncoder(),
#                                  array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazon...
#        'glipizide-metformin', 'glimepiride-pioglitazone',
#        'metformin-rosiglitazone', 'metformin-pioglitazone', 'change',
#        'diabetesMed'], dtype=object)),
#                                 ('numerical', MinMaxScaler(),
#                                  ['admission_type_id',
#                                   'discharge_disposition_id',
#                                   'time_in_hospital', 'num_lab_procedures',
#                                   'num_procedures', 'num_medications',
#                                   'number_outpatient', 'number_emergency',
#                                   'number_inpatient', 'number_diagnoses'])])

# %%
log_transformer = FunctionTransformer(np.log10)

# %%
number_processor = Pipeline([
    ("log_transformer", FunctionTransformer(lambda x: np.log10(x + EPS))),
    ("minmax", MinMaxScaler())
])

# %%
number_processor
# Out:
# Pipeline(steps=[('log_transformer',
#                  FunctionTransformer(func=<function <lambda> at 0x13cf1d620>)),
#                 ('minmax', MinMaxScaler())])

# %%
preprocessor = ColumnTransformer([
    ("categorical", OneHotEncoder(), categorical_columns),
    ("numerical", number_processor, numerical_columns)
])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('categorical', OneHotEncoder(),
#                                  array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone',
#        'acar...
#        'diabetesMed'], dtype=object)),
#                                 ('numerical',
#                                  Pipeline(steps=[('log_transformer',
#                                                   FunctionTransformer(func=<function <lambda> at 0x13cf1d620>)),
#                                                  ('minmax', MinMaxScaler())]),
#                                  ['admission_type_id',
#                                   'discharge_disposition_id',
#                                   'time_in_hospital', 'num_lab_procedures',
#                                   'num_procedures', 'num_medications',
#                                   'number_outpatient', 'number_emergency',
#                                   'number_inpatient', 'number_diagnoses'])])

# %%
pipeline = Pipeline([
    ("preprocess", preprocessor),
    ("classifier", LogisticRegression())
])

# %%
sample_attributes = sample_data.drop(columns = "readmitted")
sample_target = sample_data.readmitted

# %%
pipeline.fit(sample_attributes, sample_target)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(),
#                                                   array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'piogl...
#                                                   Pipeline(steps=[('log_transformer',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x13cf1d620>)),
#                                                                   ('minmax',
#                                                                    MinMaxScaler())]),
#                                                   ['admission_type_id',
#                                                    'discharge_disposition_id',
#                                                    'time_in_hospital',
#                                                    'num_lab_procedures',
#                                                    'num_procedures',
#                                                    'num_medications',
#                                                    'number_outpatient',
#                                                    'number_emergency',
#                                                    'number_inpatient',
#                                                    'number_diagnoses'])])),
#                 ('classifier', LogisticRegression())])

# %%
pipeline.score(sample_attributes, sample_target)
# Out:
# 0.6536

# %%
pickle.dump(logistic_regression, open("prediction_pipeline.pkl", "wb"))

# %%
pipeline.predict(sample_attributes)
# Out:
# array(['NO', 'NO', 'NO', ..., 'NO', '>30', 'NO'], dtype=object)

# %%
diabetes_data = pd.read_csv("data/diabetic_data.csv")

# %%
sample_data_2 = diabetes_data.sample(5000, random_state = 12341234)
attributes = sample_data.drop(columns = ["readmitted"])
target = sample_data.readmitted

# %%
pipeline.fit(attributes, target)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(),
#                                                   array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'piogl...
#                                                   Pipeline(steps=[('log_transformer',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x13cf1d620>)),
#                                                                   ('minmax',
#                                                                    MinMaxScaler())]),
#                                                   ['admission_type_id',
#                                                    'discharge_disposition_id',
#                                                    'time_in_hospital',
#                                                    'num_lab_procedures',
#                                                    'num_procedures',
#                                                    'num_medications',
#                                                    'number_outpatient',
#                                                    'number_emergency',
#                                                    'number_inpatient',
#                                                    'number_diagnoses'])])),
#                 ('classifier', LogisticRegression())])

# %%
pipeline["classifier"].coef_
# Out:
# array([[-0.55514279,  0.02120968,  0.04448777, ...,  0.13727923,
#          0.3915153 , -0.13270708],
#        [ 0.12678974,  0.08800068,  0.03791863, ...,  0.19328463,
#          0.18011862,  0.59068217],
#        [ 0.42835304, -0.10921036, -0.0824064 , ..., -0.33056387,
#         -0.57163392, -0.45797509]])

# %%
pipeline_reg = Pipeline([
    ("preprocess", preprocessor),
    ("classifier", LogisticRegression(C = 0.00001))
])

# %%
pipeline_reg.fit(attributes, target)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(),
#                                                   array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'piogl...
#                                                   Pipeline(steps=[('log_transformer',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x13cf1d620>)),
#                                                                   ('minmax',
#                                                                    MinMaxScaler())]),
#                                                   ['admission_type_id',
#                                                    'discharge_disposition_id',
#                                                    'time_in_hospital',
#                                                    'num_lab_procedures',
#                                                    'num_procedures',
#                                                    'num_medications',
#                                                    'number_outpatient',
#                                                    'number_emergency',
#                                                    'number_inpatient',
#                                                    'number_diagnoses'])])),
#                 ('classifier', LogisticRegression(C=1e-05))])

# %%
pipeline_reg["classifier"].coef_
# Out:
# array([[-7.88055964e-05,  3.02571721e-05, -7.33316206e-06, ...,
#          1.79056917e-04,  7.65948701e-04,  1.09658901e-04],
#        [-1.36925626e-04, -6.14118072e-05, -2.42008740e-05, ...,
#          6.62637403e-04,  1.51759689e-03,  3.15485794e-04],
#        [ 2.15731223e-04,  3.11546351e-05,  3.15340360e-05, ...,
#         -8.41694319e-04, -2.28354559e-03, -4.25144695e-04]])

# %%
train_test_split(attributes)
# Out:
# [        encounter_id  patient_nbr             race  gender      age    weight  \
#  54218      158104902     70891839  AfricanAmerican  Female  [40-50)         ?
#  56962      163012440     53776458        Caucasian  Female  [70-80)         ?
#  14311       55890654     20016900        Caucasian  Female  [70-80)         ?
#  1566        10645878     12590199        Caucasian  Female  [70-80)         ?
#  85393      270267876     67982049        Caucasian    Male  [80-90)         ?
#  ...              ...          ...              ...     ...      ...       ...
#  100121     421925582     57454947        Caucasian  Female  [70-80)         ?
#  81409      252264120     85416777        Caucasian    Male  [60-70)  [75-100)
#  6301        31419150     14364063        Caucasian  Female  [70-80)         ?
#  35956      110939484     19274094        Caucasian  Female  [70-80)         ?
#  65004      181032426     21117519        Caucasian  Female  [60-70)         ?
#
#          admission_type_id  discharge_disposition_id  admission_source_id  \
#  54218                   1                         3                    7
#  56962                   5                         3                    1
#  14311                   3                        18                    1
#  1566                    3                         3                    4
#  85393                   1                         3                    7
#  ...                   ...                       ...                  ...
#  100121                  1                         6                    7
#  81409                   3                         6                    1
#  6301                    2                         1                    1
#  35956                   1                         1                    6
#  65004                   6                         1                   17
#
#          time_in_hospital  ... examide citoglipton  insulin  \
#  54218                  9  ...      No          No     Down
#  56962                  3  ...      No          No       No
#  14311                  6  ...      No          No       No
#  1566                   7  ...      No          No   Steady
#  85393                  7  ...      No          No   Steady
#  ...                  ...  ...     ...         ...      ...
#  100121                 3  ...      No          No   Steady
#  81409                  6  ...      No          No       No
#  6301                   9  ...      No          No       No
#  35956                 11  ...      No          No   Steady
#  65004                  2  ...      No          No       No
#
#          glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
#  54218                    No                   No                        No
#  56962                    No                   No                        No
#  14311                    No                   No                        No
#  1566                     No                   No                        No
#  85393                    No                   No                        No
#  ...                     ...                  ...                       ...
#  100121                   No                   No                        No
#  81409                    No                   No                        No
#  6301                     No                   No                        No
#  35956                    No                   No                        No
#  65004                    No                   No                        No
#
#          metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
#  54218                        No                      No     Ch         Yes
#  56962                        No                      No     No          No
#  14311                        No                      No     No          No
#  1566                         No                      No     Ch         Yes
#  85393                        No                      No     No         Yes
#  ...                         ...                     ...    ...         ...
#  100121                       No                      No     No         Yes
#  81409                        No                      No     No         Yes
#  6301                         No                      No     No          No
#  35956                        No                      No     No         Yes
#  65004                        No                      No     Ch         Yes
#
#  [3750 rows x 49 columns],
#         encounter_id  patient_nbr             race  gender      age   weight  \
#  32618     103821276     28276173  AfricanAmerican    Male  [60-70)        ?
#  7932       36689646     65752038        Caucasian    Male  [30-40)        ?
#  64302     178984356     23807943  AfricanAmerican  Female  [50-60)        ?
#  91322     307814576    143288681        Caucasian  Female  [80-90)        ?
#  43579     134578080    105882327        Caucasian    Male  [80-90)  [50-75)
#  ...             ...          ...              ...     ...      ...      ...
#  23635      80765256        33264  AfricanAmerican  Female  [50-60)        ?
#  31759     101766030      2532438  AfricanAmerican  Female  [70-80)        ?
#  81130     250994418     92077083        Caucasian  Female  [60-70)        ?
#  55472     160342386    106693524        Caucasian  Female  [70-80)        ?
#  15294      58849800     81376776        Caucasian  Female  [60-70)   [0-25)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
#  32618                  5                         5                   17
#  7932                   1                         1                    7
#  64302                  1                         1                    7
#  91322                  1                         4                    7
#  43579                  1                         3                    7
#  ...                  ...                       ...                  ...
#  23635                  1                         1                    7
#  31759                  1                         1                    6
#  81130                  2                         1                    7
#  55472                  1                         3                    7
#  15294                  6                         1                   17
#
#         time_in_hospital  ... examide citoglipton  insulin  \
#  32618                 4  ...      No          No       No
#  7932                  3  ...      No          No   Steady
#  64302                 7  ...      No          No     Down
#  91322                 6  ...      No          No       No
#  43579                14  ...      No          No       No
#  ...                 ...  ...     ...         ...      ...
#  23635                 1  ...      No          No       No
#  31759                 5  ...      No          No   Steady
#  81130                 1  ...      No          No   Steady
#  55472                11  ...      No          No       No
#  15294                 5  ...      No          No       No
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
#  32618                   No                   No                        No
#  7932                    No                   No                        No
#  64302                   No                   No                        No
#  91322                   No                   No                        No
#  43579                   No                   No                        No
#  ...                    ...                  ...                       ...
#  23635                   No                   No                        No
#  31759                   No                   No                        No
#  81130                   No                   No                        No
#  55472                   No                   No                        No
#  15294                   No                   No                        No
#
#         metformin-rosiglitazone  metformin-pioglitazone change diabetesMed
#  32618                       No                      No     No          No
#  7932                        No                      No     No         Yes
#  64302                       No                      No     Ch         Yes
#  91322                       No                      No     No          No
#  43579                       No                      No     No          No
#  ...                        ...                     ...    ...         ...
#  23635                       No                      No     No          No
#  31759                       No                      No     Ch         Yes
#  81130                       No                      No     Ch         Yes
#  55472                       No                      No     Ch         Yes
#  15294                       No                      No     No          No
#
#  [1250 rows x 49 columns]]

# %%
attributes_train, attributes_test, target_train, target_test = train_test_split(
    attributes,
    target,
    test_size = 0.1,
    random_state = 121212,
    stratify = target
)

# %%
attributes_train.shape, attributes_test.shape, target_train.shape, target_test.shape
# Out:
# ((4500, 49), (500, 49), (4500,), (500,))

# %%
target.value_counts(normalize = True)
# Out:
# readmitted
# NO     0.5346
# >30    0.3514
# <30    0.1140
# Name: proportion, dtype: float64

# %%
target_train.value_counts(normalize = True)
# Out:
# readmitted
# NO     0.534667
# >30    0.351333
# <30    0.114000
# Name: proportion, dtype: float64

# %%
target_test.value_counts(normalize = True)
# Out:
# readmitted
# NO     0.534
# >30    0.352
# <30    0.114
# Name: proportion, dtype: float64

# %%
pipeline.fit(attributes_train, target_train)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(),
#                                                   array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'piogl...
#                                                   Pipeline(steps=[('log_transformer',
#                                                                    FunctionTransformer(func=<function <lambda> at 0x13cf1d620>)),
#                                                                   ('minmax',
#                                                                    MinMaxScaler())]),
#                                                   ['admission_type_id',
#                                                    'discharge_disposition_id',
#                                                    'time_in_hospital',
#                                                    'num_lab_procedures',
#                                                    'num_procedures',
#                                                    'num_medications',
#                                                    'number_outpatient',
#                                                    'number_emergency',
#                                                    'number_inpatient',
#                                                    'number_diagnoses'])])),
#                 ('classifier', LogisticRegression())])

# %%
pipeline.score(attributes_train, target_train)
# Out:
# 0.6611111111111111

# %%
pipeline.score(attributes_test, target_test)

# %%
print(classification_report(target_train, pipeline.predict(attributes_train)))
# Out:
#               precision    recall  f1-score   support
#
#          <30       0.67      0.18      0.28       513
#          >30       0.62      0.54      0.58      1581
#           NO       0.68      0.84      0.75      2406
#
#     accuracy                           0.66      4500
#    macro avg       0.66      0.52      0.54      4500
# weighted avg       0.66      0.66      0.64      4500

# %%
roc_curve(pipeline.predict_proba)

# or

roc_curve(pipeline.decision_function)

# and not .predict
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 roc_curve(pipeline.predict_proba)
#       3 # or
#       5 roc_curve(pipeline.decision_function)
#
# TypeError: roc_curve() missing 1 required positional argument: 'y_score'

# %%
cv = GridSearchCV(pipeline, param_grid = {
    "classifier__C": [1, 10, 100],
    "preprocess__numerical__minmax__feature_range": [(-1, 1), (0, 1), (-5, 5)]
}, cv = 10).fit(attributes, target)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['V71', '250.01', '959', '705', '357', '485', '601', '420', '41', '794', '664', '527', '519', '922', '935'] in column 6 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['Unknown/Invalid'] in column 1 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['Pediatrics-AllergyandImmunology', 'AllergyandImmunology'] in column 5 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['652', '800', '568', '625', '145', '473', '873', '632', '240', '983', '797', '70', '522', '78', '816'] in column 6 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['Hematology'] in column 5 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['>200'] in column 3 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['Surgery-Maxillofacial'] in column 5 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['429', '205', '250.31', '417', '875', '304', '454', '352', '250.32', '924', '183', '991', '964', '605', '534'] in column 6 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['736', '218', '585', '335', '475', '309', '152', '396', '388', '322', '283', '972', '446', '255', '865'] in column 6 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['[175-200)'] in column 3 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['V71', '250.01', '959', '705', '357', '485', '601', '420', '41', '794', '664', '527', '519', '922', '935'] in column 6 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['Surgery-Maxillofacial'] in column 5 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['429', '205', '250.31', '417', '875', '304', '454', '352', '250.32', '924', '183', '991', '964', '605', '534'] in column 6 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['736', '218', '585', '335', '475', '309', '152', '396', '388', '322', '283', '972', '446', '255', '865'] in column 6 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 444, in _passthrough_scorer
#     return estimator.score(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 718, in score
#     Xt = transform.transform(Xt)
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 800, in transform
#     Xs = self._fit_transform(
#          ^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/compose/_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/pipeline.py", line 876, in _transform_one
#     res = transformer.transform(X)
#           ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 917, in transform
#     X_int, X_mask = self._transform(
#                     ^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py", line 174, in _transform
#     raise ValueError(msg)
# ValueError: Found unknown categories ['[175-200)'] in column 3 during transform
#
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
cv.best_estimator_
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   OneHotEncoder(),
#                                                   array(['race', 'gender', 'age', 'weight', 'payer_code',
#        'medical_specialty', 'diag_1', 'diag_2', 'diag_3', 'max_glu_serum',
#        'A1Cresult', 'metformin', 'repaglinide', 'nateglinide',
#        'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide',
#        'glyburide', 'tolbutamide', 'piogl...
#                                                                    FunctionTransformer(func=<function <lambda> at 0x13cf1d620>)),
#                                                                   ('minmax',
#                                                                    MinMaxScaler(feature_range=(-1,
#                                                                                                1)))]),
#                                                   ['admission_type_id',
#                                                    'discharge_disposition_id',
#                                                    'time_in_hospital',
#                                                    'num_lab_procedures',
#                                                    'num_procedures',
#                                                    'num_medications',
#                                                    'number_outpatient',
#                                                    'number_emergency',
#                                                    'number_inpatient',
#                                                    'number_diagnoses'])])),
#                 ('classifier', LogisticRegression(C=1))])

# %%
cv.best_params_
# Out:
# {'classifier__C': 1, 'preprocess__numerical__minmax__feature_range': (-1, 1)}

# %%
cv.cv_results_
# Out:
# {'mean_fit_time': array([0.36259732, 0.36528413, 0.38364916, 0.41433687, 0.37383745,
#         0.38515785, 0.46861107, 0.43655906, 0.41420364]),
#  'std_fit_time': array([0.02694638, 0.04796   , 0.07022053, 0.02125337, 0.04679792,
#         0.04000985, 0.06384144, 0.10257405, 0.05966125]),
#  'mean_score_time': array([0.00872223, 0.00724046, 0.00732613, 0.00804622, 0.00730131,
#         0.00718019, 0.00865386, 0.00897255, 0.00826979]),
#  'std_score_time': array([0.00558287, 0.00051906, 0.00036108, 0.000887  , 0.00050358,
#         0.00038222, 0.00068029, 0.00264954, 0.00177019]),
#  'param_classifier__C': masked_array(data=[1, 1, 1, 10, 10, 10, 100, 100, 100],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_preprocess__numerical__minmax__feature_range': masked_array(data=[(-1, 1), (0, 1), (-5, 5), (-1, 1), (0, 1), (-5, 5),
#                     (-1, 1), (0, 1), (-5, 5)],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'classifier__C': 1,
#    'preprocess__numerical__minmax__feature_range': (-1, 1)},
#   {'classifier__C': 1, 'preprocess__numerical__minmax__feature_range': (0, 1)},
#   {'classifier__C': 1,
#    'preprocess__numerical__minmax__feature_range': (-5, 5)},
#   {'classifier__C': 10,
#    'preprocess__numerical__minmax__feature_range': (-1, 1)},
#   {'classifier__C': 10,
#    'preprocess__numerical__minmax__feature_range': (0, 1)},
#   {'classifier__C': 10,
#    'preprocess__numerical__minmax__feature_range': (-5, 5)},
#   {'classifier__C': 100,
#    'preprocess__numerical__minmax__feature_range': (-1, 1)},
#   {'classifier__C': 100,
#    'preprocess__numerical__minmax__feature_range': (0, 1)},
#   {'classifier__C': 100,
#    'preprocess__numerical__minmax__feature_range': (-5, 5)}],
#  'split0_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split1_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split2_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split3_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split4_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split5_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split6_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split7_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split8_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'split9_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'mean_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'std_test_score': array([nan, nan, nan, nan, nan, nan, nan, nan, nan]),
#  'rank_test_score': array([1, 1, 1, 1, 1, 1, 1, 1, 1], dtype=int32)}
